# %% [markdown]
# <img src="https://www.suitelife.blog/wp-content/uploads/2021/10/Top-50-hotel-brand-Blog-cover.jpg" alt="Top 50 Hotel Brand Blog Cover" style="width:100%; height:auto;">

# %% [markdown]
# <h2 style="color:#4CAF50;">1. <code>import pandas as pd</code></h2>
# <p style="color:#555;">This imports the <strong>pandas</strong> library, which is a powerful tool for <em>data manipulation and analysis</em>. In Kaggle, it's often used to work with structured data (like CSV files), allowing you to easily read, filter, and transform data.</p>
#
# <h2 style="color:#4CAF50;">2. <code>import numpy as np</code></h2>
# <p style="color:#555;"><strong>NumPy</strong> is the core library for numerical operations in Python. It is efficient for working with arrays and performing mathematical computations, and is commonly used for handling numeric datasets in Kaggle.</p>
#
# <h2 style="color:#4CAF50;">3. <code>from collections import Counter</code></h2>
# <p style="color:#555;">The <code>Counter</code> class from Python's <strong>collections</strong> module is used to <em>count the occurrences</em> of elements in an iterable (like lists or arrays). This is useful in Kaggle for quickly summarizing data, like counting categories.</p>
#
# <h2 style="color:#4CAF50;">4. <code>import seaborn as sns</code></h2>
# <p style="color:#555;"><strong>Seaborn</strong> is a data visualization library built on <code>matplotlib</code>. It provides high-level interfaces for making attractive and informative statistical graphics. In Kaggle, it's used for creating plots like histograms, bar plots, and heatmaps.</p>
#
# <h2 style="color:#4CAF50;">5. <code>import matplotlib.pyplot as plt</code></h2>
# <p style="color:#555;"><strong>Matplotlib</strong> is the foundational plotting library in Python. It allows for creating static, interactive, and animated visualizations. In Kaggle, it's used for detailed plot customizations alongside Seaborn.</p>
#
# <h2 style="color:#4CAF50;">6. <code>import warnings</code> and <code>warnings.simplefilter('ignore')</code></h2>
# <p style="color:#555;">The <strong>warnings</strong> module is used to handle warning messages in Python. The command <code>warnings.simplefilter('ignore')</code> is used to <em>ignore non-critical warnings</em>, preventing them from cluttering the output in Kaggle notebooks.</p>
#
# <h2 style="color:#4CAF50;">7. <code>sns.set(style="whitegrid")</code></h2>
# <p style="color:#555;">This sets the default Seaborn plot style to "whitegrid", which provides a clean, grid-based background for better readability of charts. It's commonly used in Kaggle for improving the aesthetics of data visualizations.</p>
#
# <h2 style="color:#4CAF50;">8. <code>%matplotlib inline</code></h2>
# <p style="color:#555;">This is a special command for Jupyter and Kaggle notebooks that ensures all <strong>matplotlib</strong> plots are displayed directly within the notebook. Without this, plots may not appear automatically.</p>

# %%
#importing libraries
import pandas as pd
import numpy as np

from collections import Counter
import seaborn as sns
import matplotlib.pyplot as plt

import warnings
warnings.simplefilter('ignore')

sns.set(style="whitegrid")
# %matplotlib inline

# %%
df = pd.read_csv("/kaggle/input/top-50-luxury-hotels-worldwide/Worlds Best 50 Hotels.csv", encoding='ISO-8859-1', header=0)

# %% [markdown]
# <h2 style="color:#4CAF50;">Code Explanation</h2>
#
# <pre style="background-color:#f9f9f9; padding:10px; border:1px solid #ddd;">
# df = pd.read_csv("/kaggle/input/top-50-luxury-hotels-worldwide/Worlds Best 50 Hotels.csv", encoding='ISO-8859-1', header=0)
# </pre>
#
# <h3 style="color:#4CAF50;">1. <code>df = pd.read_csv()</code></h3>
# <p style="color:#555;">This function from the <strong>pandas</strong> library reads a comma-separated values (CSV) file into a DataFrame. In Kaggle, it’s frequently used to load data for analysis. The result is assigned to the variable <code>df</code>, which stands for "DataFrame."</p>
#
# <h3 style="color:#4CAF50;">2. <code>"/kaggle/input/top-50-luxury-hotels-worldwide/Worlds Best 50 Hotels.csv"</code></h3>
# <p style="color:#555;">This is the <strong>file path</strong> to your CSV file. In Kaggle, this path refers to a dataset you uploaded. The CSV file <code>"Worlds Best 50 Hotels.csv"</code> contains data about the top 50 luxury hotels worldwide.</p>
#
# <h3 style="color:#4CAF50;">3. <code>encoding='ISO-8859-1'</code></h3>
# <p style="color:#555;">The <strong>encoding</strong> parameter specifies the character encoding used in the CSV file. In this case, <code>'ISO-8859-1'</code> is used, which is a standard encoding for western European languages. This ensures special characters are read correctly.</p>
#
# <h3 style="color:#4CAF50;">4. <code>header=0</code></h3>
# <p style="color:#555;">The <strong>header</strong> parameter tells <code>pandas</code> which row to use as the column names. <code>header=0</code> means that the first row of the CSV (index 0) will be used as the header or column names.</p>
#
# <h3 style="color:#4CAF50;">What this does:</h3>
# <p style="color:#555;">This command loads the CSV file, reads its content into a <code>pandas</code> DataFrame, and stores it in the variable <code>df</code>. The DataFrame <code>df</code> will contain rows and columns representing the data from the CSV file, allowing for easy analysis and manipulation.</p>

# %%
df.head()
# Out:
#    Rank                Name   Location  \
# 0     1     Capella Bangkok    Bangkok
# 1     2         Passalacqua  Lake Como
# 2     3  Rosewood Hong Kong  Hong Kong
# 3     4        Cheval Blanc      Paris
# 4     5     The Upper House  Hong Kong
#
#                                             Overview  Total Rooms  \
# 0  A calming riverside oasis in the centre of cac...          101
# 1  A sumptuous Lake Como retreat made for enjoyin...           24
# 2     Masterful minimalism meets marble-lined luxury          413
# 3  Uber-stylish riverside luxury and world-class ...           72
# 4               A temple of Zen high above Hong Kong          117
#
#    Starting Rate in ($)                               Dining Area  \
# 0                   600   Côte by Mauro Colagreco and Phra Nakhon
# 1                  1300                        The Garden Terrace
# 2                   650              Bluhouse and The Dining Room
# ...

# %% [markdown]
# <h2 style="color:#4CAF50;">Code Explanation</h2>
#
# <pre style="background-color:#f9f9f9; padding:10px; border:1px solid #ddd;">
# df.head()
# </pre>
#
# <h3 style="color:#4CAF50;">1. <code>df.head()</code></h3>
# <p style="color:#555;">The <code>head()</code> method is a built-in function of a <strong>pandas</strong> DataFrame that returns the first five rows of the DataFrame by default.</p>
#
# <h3 style="color:#4CAF50;">2. Purpose:</h3>
# <p style="color:#555;">This function is particularly useful for quickly inspecting the data structure and contents, allowing you to see the top rows without printing the entire DataFrame.</p>
#
# <h3 style="color:#4CAF50;">3. Example Output:</h3>
# <p style="color:#555;">When you run <code>df.head()</code>, it will display the first five rows of the DataFrame <code>df</code>, showing you the data and the column names. This helps in understanding the data types and values present in the dataset.</p>

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 50 entries, 0 to 49
# Data columns (total 11 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   Rank                  50 non-null     int64
#  1   Name                  50 non-null     object
#  2   Location              50 non-null     object
#  3   Overview              50 non-null     object
#  4   Total Rooms           50 non-null     int64
#  5   Starting Rate in ($)  50 non-null     int64
#  6   Dining Area           50 non-null     object
#  7   Drinking Area         46 non-null     object
#  8   Hotel Ammenties       49 non-null     object
#  9   Address               50 non-null     object
#  10  Number                48 non-null     object
# dtypes: int64(3), object(8)
# memory usage: 4.4+ KB

# %% [markdown]
# <h2 style="color:#4CAF50;">Code Explanation</h2>
#
# <pre style="background-color:#f9f9f9; padding:10px; border:1px solid #ddd;">
# df.info()
# </pre>
#
# <h3 style="color:#4CAF50;">1. <code>df.info()</code></h3>
# <p style="color:#555;">The <code>info()</code> method is a built-in function of a <strong>pandas</strong> DataFrame that provides a summary of the DataFrame, including key information about its structure.</p>
#
# <h3 style="color:#4CAF50;">2. Purpose:</h3>
# <p style="color:#555;">This method is useful for understanding the DataFrame's shape, data types, and the presence of missing values. It helps in getting a quick overview of the dataset before performing any analysis.</p>
#
# <h3 style="color:#4CAF50;">3. Example Output:</h3>
# <pre style="background-color:#f9f9f9; padding:10px; border:1px solid #ddd;">
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 50 entries, 0 to 49
# Data columns (total 11 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   Rank                  50 non-null     int64
#  1   Name                  50 non-null     object
#  2   Location              50 non-null     object
#  3   Overview              50 non-null     object
#  4   Total Rooms           50 non-null     int64
#  5   Starting Rate in ($)  50 non-null     int64
#  6   Dining Area           50 non-null     object
#  7   Drinking Area         46 non-null     object
#  8   Hotel Ammenties       49 non-null     object
#  9   Address               50 non-null     object
#  10  Number                48 non-null     object
# dtypes: int64(3), object(8)
# memory usage: 4.4+ KB
# </pre>
#
# <h3 style="color:#4CAF50;">4. Breakdown of Output:</h3>
# <ul style="color:#555;">
#     <li><strong>RangeIndex:</strong> 50 entries, indexed from 0 to 49.</li>
#     <li><strong>Data columns:</strong> The DataFrame contains 11 columns.</li>
#     <li><strong>Non-Null Count:</strong> Shows the count of non-null entries for each column.</li>
#     <li><strong>Dtype:</strong> Indicates the data type of each column (e.g., <code>int64</code>, <code>object</code>).</li>
#     <li><strong>Memory usage:</strong> Displays the memory consumed by the DataFrame.</li>
# </ul>

# %%
print(f"Dataset contains {df.shape[0]} rows and {df.shape[1]} columns.\n")
# Out:
# Dataset contains 50 rows and 11 columns.

# %% [markdown]
# <h2 style="color:#4CAF50;">Code Explanation</h2>
#
# <pre style="background-color:#f9f9f9; padding:10px; border:1px solid #ddd;">
# print(f"Dataset contains {df.shape[0]} rows and {df.shape[1]} columns.\n")
# </pre>
#
# <h3 style="color:#4CAF50;">1. <code>print()</code></h3>
# <p style="color:#555;">The <code>print()</code> function outputs the specified message to the console.</p>
#
# <h3 style="color:#4CAF50;">2. <code>f"..."</code> (f-string):</h3>
# <p style="color:#555;">An <strong>f-string</strong> (formatted string literal) allows you to embed expressions inside string literals, using curly braces <code>{}</code> to include variables or expressions directly in the string.</p>
#
# <h3 style="color:#4CAF50;">3. <code>df.shape</code></h3>
# <p style="color:#555;">The <code>shape</code> attribute of a DataFrame returns a tuple representing its dimensionality: <code>(number of rows, number of columns)</code>. In this case, <code>df.shape[0]</code> gives the number of rows, and <code>df.shape[1]</code> gives the number of columns.</p>
#
# <h3 style="color:#4CAF50;">4. Output:</h3>
# <p style="color:#555;">When you run this code, it will print a statement similar to:</p>
# <pre style="background-color:#f9f9f9; padding:10px; border:1px solid #ddd;">
# Dataset contains 50 rows and 11 columns.
# </pre>
#
# <h3 style="color:#4CAF50;">5. Purpose:</h3>
# <p style="color:#555;">This code provides a quick overview of the dataset's size, helping you understand how much data you are working with before performing further analysis.</p>

# %%
print("Missing values in each column:")
print(df.isnull().sum())
# Out:
# Missing values in each column:
# Rank                    0
# Name                    0
# Location                0
# Overview                0
# Total Rooms             0
# Starting Rate in ($)    0
# Dining Area             0
# Drinking Area           4
# Hotel Ammenties         1
# Address                 0
# Number                  2
# dtype: int64

# %% [markdown]
# <h2 style="color:#4CAF50;">Code Explanation</h2>
#
# <pre style="background-color:#f9f9f9; padding:10px; border:1px solid #ddd;">
# print("Missing values in each column:")
# print(df.isnull().sum())
# </pre>
#
# <h3 style="color:#4CAF50;">1. <code>print()</code></h3>
# <p style="color:#555;">The <code>print()</code> function outputs the specified message to the console.</p>
#
# <h3 style="color:#4CAF50;">2. <code>df.isnull()</code></h3>
# <p style="color:#555;">The <code>isnull()</code> method returns a DataFrame of the same shape as <code>df</code>, where each cell contains <code>True</code> if the corresponding value is <strong>missing</strong> (i.e., <code>NaN</code>) and <code>False</code> otherwise.</p>
#
# <h3 style="color:#4CAF50;">3. <code>sum()</code></h3>
# <p style="color:#555;">The <code>sum()</code> method, when called on a DataFrame of boolean values, counts the number of <code>True</code> values in each column, which corresponds to the number of missing values.</p>
#
# <h3 style="color:#4CAF50;">4. Output:</h3>
# <p style="color:#555;">When you run this code, it will print a statement followed by the count of missing values in each column, similar to:</p>
# <pre style="background-color:#f9f9f9; padding:10px; border:1px solid #ddd;">
# Missing values in each column:
# Rank                  0
# Name                  0
# Location              0
# Overview              0
# Total Rooms           0
# Starting Rate in ($)  0
# Dining Area           0
# Drinking Area         4
# Hotel Ammenties       1
# Address               0
# Number                2
# dtype: int64
# </pre>
#
# <h3 style="color:#4CAF50;">5. Purpose:</h3>
# <p style="color:#555;">This code helps identify missing values in the dataset, which is crucial for data cleaning and preprocessing steps before analysis or modeling.</p>

# %%
print("\nData types of each column:")
print(df.dtypes)
# Out:
# Data types of each column:
# Rank                     int64
# Name                    object
# Location                object
# Overview                object
# Total Rooms              int64
# Starting Rate in ($)     int64
# Dining Area             object
# Drinking Area           object
# Hotel Ammenties         object
# Address                 object
# Number                  object
# dtype: object

# %% [markdown]
# <h2 style="color:#4CAF50;">Code Explanation</h2>
#
# <pre style="background-color:#f9f9f9; padding:10px; border:1px solid #ddd;">
# print("\nData types of each column:")
# print(df.dtypes)
# </pre>
#
#
#
# <h3 style="color:#4CAF50;">1. <code>df.dtypes</code></h3>
# <p style="color:#555;">The <code>dtypes</code> attribute of a DataFrame returns a Series containing the data types of each column. This helps you understand the nature of the data you are working with.</p>

# %%
df = df.drop(['Number'], axis=1)

# %% [markdown]
# <h2 style="color:#4CAF50;">Code Explanation</h2>
#
# <pre style="background-color:#f9f9f9; padding:10px; border:1px solid #ddd;">
# df = df.drop(['Number'], axis=1)
# </pre>
#
# <h3 style="color:#4CAF50;">1. <code>df.drop()</code></h3>
# <p style="color:#555;">The <code>drop()</code> method is used to remove specified labels from rows or columns of a DataFrame. In this case, it is used to drop a column.</p>
#
# <h3 style="color:#4CAF50;">2. Parameters:</h3>
# <ul style="color:#555;">
#     <li><strong><code>['Number']</code></strong>: The name of the column to be removed. This should be a list even if you are dropping a single column.</li>
#     <li><strong><code>axis=1</code></strong>: Specifies that the operation should be performed on columns. Use <code>axis=0</code> for rows.</li>
# </ul>
#
# <h3 style="color:#4CAF50;">3. Assignment:</h3>
# <p style="color:#555;">The result of the <code>drop()</code> operation is reassigned to <code>df</code>, effectively updating the DataFrame to exclude the "Number" column.</p>
#
# <h3 style="color:#4CAF50;">4. Purpose:</h3>
# <p style="color:#555;">This code is useful for cleaning the dataset by removing unnecessary or irrelevant columns, which can simplify further analysis and processing.</p>

# %% [markdown]
# # PLOTS

# %%
plt.figure(figsize=(10, 6))
sns.histplot(df['Starting Rate in ($)'], kde=True, color='lavender', bins=15)

plt.title('Distribution of Starting Rates of Hotels', fontsize=16)
plt.xlabel('Starting Rate in ($)', fontsize=12)
plt.ylabel('Frequency', fontsize=12)
plt.show()

# %% [markdown]
# <h2 style="color:#4CAF50;">Code Explanation</h2>
#
# <pre style="background-color:#f9f9f9; padding:10px; border:1px solid #ddd;">
# plt.figure(figsize=(10, 6))
# sns.histplot(df['Starting Rate in ($)'], kde=True, color='teal', bins=15)
#
# plt.title('Distribution of Starting Rates of Hotels', fontsize=16)
# plt.xlabel('Starting Rate in ($)', fontsize=12)
# plt.ylabel('Frequency', fontsize=12)
# plt.show()
# </pre>
#
# <h3 style="color:#4CAF50;">1. <code>plt.figure(figsize=(10, 6))</code></h3>
# <p style="color:#555;">This line initializes a new figure for the plot, with a specified size of 10 inches wide and 6 inches tall.</p>
#
# <h3 style="color:#4CAF50;">2. <code>sns.histplot()</code></h3>
# <p style="color:#555;">The <code>histplot()</code> function from Seaborn creates a histogram to visualize the distribution of data. The parameters used are:</p>
# <ul style="color:#555;">
#     <li><strong><code>df['Starting Rate in ($)']</code></strong>: The data to be plotted, specifically the "Starting Rate in ($)" column from the DataFrame.</li>
#     <li><strong><code>kde=True</code></strong>: This adds a Kernel Density Estimate curve to the histogram, providing a smoother representation of the distribution.</li>
#     <li><strong><code>color='lavender'</code></strong>: Sets the color of the histogram bars to lavender.</li>
#     <li><strong><code>bins=15</code></strong>: Specifies the number of bins (intervals) for the histogram, determining how the data will be grouped.</li>
# </ul>
#
# <h3 style="color:#4CAF50;">3. Title and Labels:</h3>
# <p style="color:#555;">The following lines add a title and axis labels to the plot:</p>
# <ul style="color:#555;">
#     <li><strong><code>plt.title('Distribution of Starting Rates of Hotels', fontsize=16)</code></strong>: Sets the title of the plot with a font size of 16.</li>
#     <li><strong><code>plt.xlabel('Starting Rate in ($)', fontsize=12)</code></strong>: Labels the x-axis with the specified text and font size.</li>
#     <li><strong><code>plt.ylabel('Frequency', fontsize=12)</code></strong>: Labels the y-axis similarly.</li>
# </ul>
#
# <h3 style="color:#4CAF50;">4. <code>plt.show()</code></h3>
# <p style="color:#555;">Finally, the <code>show()</code> function displays the plot.</p>
#
# <h3 style="color:#4CAF50;">5. Purpose:</h3>
# <p style="color:#555;">This code visualizes the distribution of starting rates for hotels, allowing you to understand the frequency and spread of rates within the dataset, which is crucial for data analysis and decision-making.</p>

# %% [markdown]
# # Overall, the data suggests that while most of the top 50 hotels have starting rates between 500 and 2000 dollars, there are some luxury hotels with much higher rates.

# %%
# Grouped this by location and calculated mean starting rate
location_rates = df.groupby('Location')['Starting Rate in ($)'].mean().sort_values()

plt.figure(figsize=(12, 6))
sns.barplot(x=location_rates.index, y=location_rates.values, palette='coolwarm')

plt.title('Average Starting Rates by Location', fontsize=16)
plt.xlabel('Location', fontsize=12)
plt.ylabel('Average Starting Rate in ($)', fontsize=12)

plt.xticks(rotation=90, ha='right')
plt.tight_layout()
plt.show()

# %% [markdown]
# <h2 style="color:#4CAF50;">Code Explanation</h2>
#
# <pre style="background-color:#f9f9f9; padding:10px; border:1px solid #ddd;">
# # Grouped this by location and calculated mean starting rate
# location_rates = df.groupby('Location')['Starting Rate in ($)'].mean().sort_values()
#
# plt.figure(figsize=(12, 6))
# sns.barplot(x=location_rates.index, y=location_rates.values, palette='coolwarm')
#
# plt.title('Average Starting Rates by Location', fontsize=16)
# plt.xlabel('Location', fontsize=12)
# plt.ylabel('Average Starting Rate in ($)', fontsize=12)
#
# plt.xticks(rotation=90, ha='right')
# plt.tight_layout()
# plt.show()
# </pre>
#
# <h3 style="color:#4CAF50;">1. <code>df.groupby()</code></h3>
# <p style="color:#555;">The <code>groupby()</code> method is used to group the DataFrame by the specified column, in this case, 'Location'. It allows for aggregation functions to be applied to each group.</p>
#
# <h3 style="color:#4CAF50;">2. <code>mean()</code></h3>
# <p style="color:#555;">The <code>mean()</code> function calculates the average of the 'Starting Rate in ($)' for each location group. The results are then sorted in ascending order using <code>sort_values()</code>.</p>
#
# <h3 style="color:#4CAF50;">3. Bar Plot Creation:</h3>
# <ul style="color:#555;">
#     <li><strong><code>plt.figure(figsize=(12, 6))</code></strong>: Initializes a new figure with a size of 12 inches wide and 6 inches tall.</li>
#     <li><strong><code>sns.barplot()</code></strong>: Creates a bar plot using Seaborn with the following parameters:</li>
#     <ul style="color:#555;">
#         <li><strong><code>x=location_rates.index</code></strong>: The x-axis represents the locations.</li>
#         <li><strong><code>y=location_rates.values</code></strong>: The y-axis represents the average starting rates.</li>
#         <li><strong><code>palette='coolwarm'</code></strong>: Specifies the color palette used for the bars.</li>
#     </ul>
# </ul>
#
# <h3 style="color:#4CAF50;">4. Title and Labels:</h3>
# <p style="color:#555;">The following lines add a title and axis labels to the plot:</p>
# <ul style="color:#555;">
#     <li><strong><code>plt.title('Average Starting Rates by Location', fontsize=16)</code></strong>: Sets the title of the plot with a font size of 16.</li>
#     <li><strong><code>plt.xlabel('Location', fontsize=12)</code></strong>: Labels the x-axis with the specified text and font size.</li>
#     <li><strong><code>plt.ylabel('Average Starting Rate in ($)', fontsize=12)</code></strong>: Labels the y-axis similarly.</li>
# </ul>
#
# <h3 style="color:#4CAF50;">5. Rotation and Layout:</h3>
# <ul style="color:#555;">
#     <li><strong><code>plt.xticks(rotation=90, ha='right')</code></strong>: Rotates the x-axis tick labels by 90 degrees for better readability, aligning them to the right.</li>
#     <li><strong><code>plt.tight_layout()</code></strong>: Adjusts the layout of the plot to make sure everything fits well without overlap.</li>
# </ul>
#
# <h3 style="color:#4CAF50;">6. <code>plt.show()</code></h3>
# <p style="color:#555;">Finally, the <code>show()</code> function displays the plot.</p>
#
# <h3 style="color:#4CAF50;">7. Purpose:</h3>
# <p style="color:#555;">This code visualizes the average starting rates of hotels by location, enabling you to quickly compare prices across different locations and gain insights into regional pricing trends.</p>

# %% [markdown]
# > # Highest Average Rate: The Maldives has the highest average starting rate among all the locations.
# > # Lowest Average Rate: Hobart has the lowest average starting rate.
# > # Clustering: There are clusters of locations with similar average rates. For example, locations in Asia tend to have lower average rates compared to locations in Europe and North America.

# %% [markdown]
# # **Total Rooms vs. Starting Rates**

# %%
plt.figure(figsize=(10, 6))
sns.scatterplot(data=df, x='Total Rooms', y='Starting Rate in ($)', hue='Location', palette='viridis', s=100)

plt.title('Total Rooms vs. Starting Rates of Hotels', fontsize=16)
plt.xlabel('Total Rooms', fontsize=12)
plt.ylabel('Starting Rate in ($)', fontsize=12)
plt.legend(loc='upper right', title='Location')
plt.tight_layout()
plt.show()

# %% [markdown]
# <h2 style="color:#4CAF50;">Code Explanation</h2>
#
# <pre style="background-color:#f9f9f9; padding:10px; border:1px solid #ddd;">
# plt.figure(figsize=(10, 6))
# sns.scatterplot(data=df, x='Total Rooms', y='Starting Rate in ($)', hue='Location', palette='viridis', s=100)
#
# plt.title('Total Rooms vs. Starting Rates of Hotels', fontsize=16)
# plt.xlabel('Total Rooms', fontsize=12)
# plt.ylabel('Starting Rate in ($)', fontsize=12)
# plt.legend(loc='upper right', title='Location')
# plt.tight_layout()
# plt.show()
# </pre>
#
# <h3 style="color:#4CAF50;">1. <code>plt.figure(figsize=(10, 6))</code></h3>
# <p style="color:#555;">This line initializes a new figure for the plot, with a specified size of 10 inches wide and 6 inches tall.</p>
#
# <h3 style="color:#4CAF50;">2. <code>sns.scatterplot()</code></h3>
# <p style="color:#555;">The <code>scatterplot()</code> function from Seaborn creates a scatter plot to visualize the relationship between two numeric variables. The parameters used are:</p>
# <ul style="color:#555;">
#     <li><strong><code>data=df</code></strong>: Specifies the DataFrame from which the data will be taken.</li>
#     <li><strong><code>x='Total Rooms'</code></strong>: Sets the x-axis to represent the total number of rooms in the hotels.</li>
#     <li><strong><code>y='Starting Rate in ($)'</code></strong>: Sets the y-axis to represent the starting rates of the hotels.</li>
#     <li><strong><code>hue='Location'</code></strong>: Uses different colors to differentiate points based on hotel locations.</li>
#     <li><strong><code>palette='viridis'</code></strong>: Specifies the color palette for the scatter plot.</li>
#     <li><strong><code>s=100</code></strong>: Sets the size of the scatter plot markers to 100.</li>
# </ul>
#
# <h3 style="color:#4CAF50;">3. Title and Labels:</h3>
# <p style="color:#555;">The following lines add a title and axis labels to the plot:</p>
# <ul style="color:#555;">
#     <li><strong><code>plt.title('Total Rooms vs. Starting Rates of Hotels', fontsize=16)</code></strong>: Sets the title of the plot with a font size of 16.</li>
#     <li><strong><code>plt.xlabel('Total Rooms', fontsize=12)</code></strong>: Labels the x-axis with the specified text and font size.</li>
#     <li><strong><code>plt.ylabel('Starting Rate in ($)', fontsize=12)</code></strong>: Labels the y-axis similarly.</li>
# </ul>
#
# <h3 style="color:#4CAF50;">4. Legend:</h3>
# <p style="color:#555;">The following line adds a legend to the plot:</p>
# <ul style="color:#555;">
#     <li><strong><code>plt.legend(loc='upper right', title='Location')</code></strong>: Places the legend in the upper right corner of the plot, with the title 'Location'.</li>
# </ul>
#
# <h3 style="color:#4CAF50;">5. <code>plt.tight_layout()</code></h3>
# <p style="color:#555;">This function adjusts the layout of the plot to ensure that elements fit well without overlap.</p>
#
# <h3 style="color:#4CAF50;">6. <code>plt.show()</code></h3>
# <p style="color:#555;">Finally, the <code>show()</code> function displays the plot.</p>
#
# <h3 style="color:#4CAF50;">7. Purpose:</h3>
# <p style="color:#555;">This code visualizes the relationship between the total number of rooms in hotels and their starting rates, allowing for insights into how room quantity affects pricing across different locations.</p>

# %% [markdown]
# # Top 5 Dining Areas by Location Based on Max Price

# %%
# Grouped this by Dining Area and Location, and calculated the max Starting Rate
top_dining_areas = df.groupby('Dining Area')['Starting Rate in ($)'].max().sort_values(ascending=False).head(5)

plt.figure(figsize=(10, 6))
sns.barplot(x=top_dining_areas.values, y=top_dining_areas.index, palette='coolwarm')

plt.title('Top 5 Dining Areas by Max Starting Rate', fontsize=16)
plt.xlabel('Max Starting Rate in ($)', fontsize=12)
plt.ylabel('Dining Area', fontsize=12)

plt.tight_layout()
plt.show()

# %% [markdown]
# <h2 style="color:#4CAF50;">Code Explanation</h2>
#
# <pre style="background-color:#f9f9f9; padding:10px; border:1px solid #ddd;">
# # Grouped this by Dining Area and Location, and calculated the max Starting Rate
# top_dining_areas = df.groupby('Dining Area')['Starting Rate in ($)'].max().sort_values(ascending=False).head(5)
#
# plt.figure(figsize=(10, 6))
# sns.barplot(x=top_dining_areas.values, y=top_dining_areas.index, palette='coolwarm')
#
# plt.title('Top 5 Dining Areas by Max Starting Rate', fontsize=16)
# plt.xlabel('Max Starting Rate in ($)', fontsize=12)
# plt.ylabel('Dining Area', fontsize=12)
#
# plt.tight_layout()
# plt.show()
# </pre>
#
# <h3 style="color:#4CAF50;">1. Grouping and Calculating Maximum Starting Rate:</h3>
# <p style="color:#555;">The first line of code groups the DataFrame <code>df</code> by the <code>Dining Area</code> column and calculates the maximum starting rate for each dining area:</p>
# <ul style="color:#555;">
#     <li><strong><code>df.groupby('Dining Area')['Starting Rate in ($)'].max()</code></strong>: Groups the data by dining area and calculates the maximum starting rate within each group.</li>
#     <li><strong><code>.sort_values(ascending=False)</code></strong>: Sorts the results in descending order, placing the highest starting rates at the top.</li>
#     <li><strong><code>.head(5)</code></strong>: Retrieves the top 5 dining areas with the highest maximum starting rates.</li>
# </ul>
#
# <h3 style="color:#4CAF50;">2. Create a Figure:</h3>
# <p style="color:#555;">The following line initializes a new figure for the plot with specified dimensions:</p>
# <ul style="color:#555;">
#     <li><strong><code>plt.figure(figsize=(10, 6))</code></strong>: Creates a figure that is 10 inches wide and 6 inches tall.</li>
# </ul>
#
# <h3 style="color:#4CAF50;">3. Creating a Bar Plot:</h3>
# <p style="color:#555;">The <code>barplot()</code> function from Seaborn is used to create a horizontal bar plot:</p>
# <ul style="color:#555;">
#     <li><strong><code>sns.barplot(x=top_dining_areas.values, y=top_dining_areas.index, palette='coolwarm')</code></strong>:
#         <ul>
#             <li><code>x=top_dining_areas.values</code>: Sets the x-axis to represent the maximum starting rates.</li>
#             <li><code>y=top_dining_areas.index</code>: Sets the y-axis to represent the dining areas.</li>
#             <li><code>palette='coolwarm'</code>: Specifies a color palette for the bars, transitioning from cool to warm colors.</li>
#         </ul>
#     </li>
# </ul>
#
# <h3 style="color:#4CAF50;">4. Adding Title and Labels:</h3>
# <p style="color:#555;">The following lines add a title and axis labels to the plot:</p>
# <ul style="color:#555;">
#     <li><strong><code>plt.title('Top 5 Dining Areas by Max Starting Rate', fontsize=16)</code></strong>: Sets the title of the plot with a font size of 16.</li>
#     <li><strong><code>plt.xlabel('Max Starting Rate in ($)', fontsize=12)</code></strong>: Labels the x-axis with the specified text and font size.</li>
#     <li><strong><code>plt.ylabel('Dining Area', fontsize=12)</code></strong>: Labels the y-axis similarly.</li>
# </ul>
#
# <h3 style="color:#4CAF50;">5. Layout Adjustment:</h3>
# <p style="color:#555;">The line below ensures that the plot elements fit well without overlapping:</p>
# <ul style="color:#555;">
#     <li><strong><code>plt.tight_layout()</code></strong>: Adjusts the plot layout for better visibility.</li>
# </ul>
#
# <h3 style="color:#4CAF50;">6. Displaying the Plot:</h3>
# <p style="color:#555;"><code>plt.show()</code>: This function displays the plot on the screen.</p>
#
# <h3 style="color:#4CAF50;">7. Purpose:</h3>
# <p style="color:#555;">This code visualizes the top 5 dining areas based on the maximum starting rates of hotels, allowing insights into which dining areas command higher prices.</p>

# %% [markdown]
# # Top 5 Drinking Areas by Location Based on Max Price

# %%
# Grouped this by Drinking Area and Location, and calculated the max Starting Rate
top_drinking_areas = df.groupby('Drinking Area')['Starting Rate in ($)'].max().sort_values(ascending=False).head(5)

plt.figure(figsize=(10, 6))
sns.barplot(x=top_drinking_areas.values, y=top_drinking_areas.index, palette='magma')

plt.title('Top 5 Drinking Areas by Max Starting Rate', fontsize=16)
plt.xlabel('Max Starting Rate in ($)', fontsize=12)
plt.ylabel('Drinking Area', fontsize=12)

plt.tight_layout()
plt.show()

# %% [markdown]
# <h2 style="color:#4CAF50;">Code Explanation</h2>
#
# <pre style="background-color:#f9f9f9; padding:10px; border:1px solid #ddd;">
# # Grouped this by Drinking Area and Location, and calculated the max Starting Rate
# top_drinking_areas = df.groupby('Drinking Area')['Starting Rate in ($)'].max().sort_values(ascending=False).head(5)
#
# plt.figure(figsize=(10, 6))
# sns.barplot(x=top_drinking_areas.values, y=top_drinking_areas.index, palette='magma')
#
# plt.title('Top 5 Drinking Areas by Max Starting Rate', fontsize=16)
# plt.xlabel('Max Starting Rate in ($)', fontsize=12)
# plt.ylabel('Drinking Area', fontsize=12)
#
# plt.tight_layout()
# plt.show()
# </pre>
#
# <h3 style="color:#4CAF50;">1. Grouping and Calculating Maximum Starting Rate:</h3>
# <p style="color:#555;">The first line of code groups the DataFrame <code>df</code> by the <code>Drinking Area</code> column and calculates the maximum starting rate for each drinking area:</p>
# <ul style="color:#555;">
#     <li><strong><code>df.groupby('Drinking Area')['Starting Rate in ($)'].max()</code></strong>: Groups the data by drinking area and calculates the maximum starting rate within each group.</li>
#     <li><strong><code>.sort_values(ascending=False)</code></strong>: Sorts the results in descending order, placing the highest starting rates at the top.</li>
#     <li><strong><code>.head(5)</code></strong>: Retrieves the top 5 drinking areas with the highest maximum starting rates.</li>
# </ul>
#
# <h3 style="color:#4CAF50;">2. Create a Figure:</h3>
# <p style="color:#555;">The following line initializes a new figure for the plot with specified dimensions:</p>
# <ul style="color:#555;">
#     <li><strong><code>plt.figure(figsize=(10, 6))</code></strong>: Creates a figure that is 10 inches wide and 6 inches tall.</li>
# </ul>
#
# <h3 style="color:#4CAF50;">3. Creating a Bar Plot:</h3>
# <p style="color:#555;">The <code>barplot()</code> function from Seaborn is used to create a horizontal bar plot:</p>
# <ul style="color:#555;">
#     <li><strong><code>sns.barplot(x=top_drinking_areas.values, y=top_drinking_areas.index, palette='magma')</code></strong>:
#         <ul>
#             <li><code>x=top_drinking_areas.values</code>: Sets the x-axis to represent the maximum starting rates.</li>
#             <li><code>y=top_drinking_areas.index</code>: Sets the y-axis to represent the drinking areas.</li>
#             <li><code>palette='magma'</code>: Specifies a color palette for the bars, transitioning through warm colors.</li>
#         </ul>
#     </li>
# </ul>
#
# <h3 style="color:#4CAF50;">4. Adding Title and Labels:</h3>
# <p style="color:#555;">The following lines add a title and axis labels to the plot:</p>
# <ul style="color:#555;">
#     <li><strong><code>plt.title('Top 5 Drinking Areas by Max Starting Rate', fontsize=16)</code></strong>: Sets the title of the plot with a font size of 16.</li>
#     <li><strong><code>plt.xlabel('Max Starting Rate in ($)', fontsize=12)</code></strong>: Labels the x-axis with the specified text and font size.</li>
#     <li><strong><code>plt.ylabel('Drinking Area', fontsize=12)</code></strong>: Labels the y-axis similarly.</li>
# </ul>
#
# <h3 style="color:#4CAF50;">5. Layout Adjustment:</h3>
# <p style="color:#555;">The line below ensures that the plot elements fit well without overlapping:</p>
# <ul style="color:#555;">
#     <li><strong><code>plt.tight_layout()</code></strong>: Adjusts the plot layout for better visibility.</li>
# </ul>
#
# <h3 style="color:#4CAF50;">6. Displaying the Plot:</h3>
# <p style="color:#555;"><code>plt.show()</code>: This function displays the plot on the screen.</p>
#
# <h3 style="color:#4CAF50;">7. Purpose:</h3>
# <p style="color:#555;">This code visualizes the top 5 drinking areas based on the maximum starting rates of hotels, providing insights into which drinking areas have the highest prices.</p>

# %% [markdown]
# # Most Common Amenities

# %%
 # Splitting the amenities by comma and flattend the list
all_amenities = df['Hotel Ammenties'].str.split(',').explode().str.strip()

# Counting the frequency of each amenity
amenity_counts = Counter(all_amenities)
top_amenities = pd.DataFrame(amenity_counts.most_common(10), columns=['Amenity', 'Count'])

plt.figure(figsize=(10, 6))
sns.barplot(x='Count', y='Amenity', data=top_amenities, palette='viridis')

plt.title('Top 10 Most Common Hotel Amenities', fontsize=16)
plt.xlabel('Count', fontsize=12)
plt.ylabel('Amenity', fontsize=12)
plt.tight_layout()
plt.show()

# %% [markdown]
# <h2 style="color:#4CAF50;">Code Explanation</h2>
#
# <pre style="background-color:#f9f9f9; padding:10px; border:1px solid #ddd;">
# # Splitting the amenities by comma and flattening the list
# all_amenities = df['Hotel Ammenties'].str.split(',').explode().str.strip()
#
# # Counting the frequency of each amenity
# amenity_counts = Counter(all_amenities)
# top_amenities = pd.DataFrame(amenity_counts.most_common(10), columns=['Amenity', 'Count'])
#
# plt.figure(figsize=(10, 6))
# sns.barplot(x='Count', y='Amenity', data=top_amenities, palette='viridis')
#
# plt.title('Top 10 Most Common Hotel Amenities', fontsize=16)
# plt.xlabel('Count', fontsize=12)
# plt.ylabel('Amenity', fontsize=12)
# plt.tight_layout()
# plt.show()
# </pre>
#
# <h3 style="color:#4CAF50;">1. Splitting Amenities:</h3>
# <p style="color:#555;">The first line of code splits the <code>Hotel Ammenties</code> column in the DataFrame <code>df</code> by commas and flattens the resulting list:</p>
# <ul style="color:#555;">
#     <li><strong><code>df['Hotel Ammenties'].str.split(',')</code></strong>: Splits the string in each row into a list of amenities.</li>
#     <li><strong><code>.explode()</code></strong>: Flattens the lists so that each amenity appears in its own row.</li>
#     <li><strong><code>.str.strip()</code></strong>: Removes any leading or trailing whitespace from the amenities.</li>
# </ul>
#
# <h3 style="color:#4CAF50;">2. Counting Amenities:</h3>
# <p style="color:#555;">The next lines of code count the frequency of each amenity:</p>
# <ul style="color:#555;">
#     <li><strong><code>Counter(all_amenities)</code></strong>: Creates a counter object that counts the occurrences of each amenity.</li>
#     <li><strong><code>pd.DataFrame(amenity_counts.most_common(10), columns=['Amenity', 'Count'])</code></strong>:
#         <ul>
#             <li>Converts the 10 most common amenities and their counts into a DataFrame.</li>
#         </ul>
#     </li>
# </ul>
#
# <h3 style="color:#4CAF50;">3. Create a Figure:</h3>
# <p style="color:#555;">This line initializes a new figure for the plot with specified dimensions:</p>
# <ul style="color:#555;">
#     <li><strong><code>plt.figure(figsize=(10, 6))</code></strong>: Creates a figure that is 10 inches wide and 6 inches tall.</li>
# </ul>
#
# <h3 style="color:#4CAF50;">4. Creating a Bar Plot:</h3>
# <p style="color:#555;">The <code>barplot()</code> function from Seaborn is used to create a horizontal bar plot:</p>
# <ul style="color:#555;">
#     <li><strong><code>sns.barplot(x='Count', y='Amenity', data=top_amenities, palette='viridis')</code></strong>:
#         <ul>
#             <li><code>x='Count'</code>: Sets the x-axis to represent the counts of the amenities.</li>
#             <li><code>y='Amenity'</code>: Sets the y-axis to represent the amenities themselves.</li>
#             <li><code>palette='viridis'</code>: Specifies a color palette that transitions through green to yellow.</li>
#         </ul>
#     </li>
# </ul>
#
# <h3 style="color:#4CAF50;">5. Adding Title and Labels:</h3>
# <p style="color:#555;">The following lines add a title and axis labels to the plot:</p>
# <ul style="color:#555;">
#     <li><strong><code>plt.title('Top 10 Most Common Hotel Amenities', fontsize=16)</code></strong>: Sets the title of the plot with a font size of 16.</li>
#     <li><strong><code>plt.xlabel('Count', fontsize=12)</code></strong>: Labels the x-axis with the specified text and font size.</li>
#     <li><strong><code>plt.ylabel('Amenity', fontsize=12)</code></strong>: Labels the y-axis similarly.</li>
# </ul>
#
# <h3 style="color:#4CAF50;">6. Layout Adjustment:</h3>
# <p style="color:#555;">The line below ensures that the plot elements fit well without overlapping:</p>
# <ul style="color:#555;">
#     <li><strong><code>plt.tight_layout()</code></strong>: Adjusts the plot layout for better visibility.</li>
# </ul>
#
# <h3 style="color:#4CAF50;">7. Displaying the Plot:</h3>
# <p style="color:#555;"><code>plt.show()</code>: This function displays the plot on the screen.</p>
#
# <h3 style="color:#4CAF50;">8. Purpose:</h3>
# <p style="color:#555;">This code visualizes the top 10 most common hotel amenities, providing insights into what amenities are most frequently offered in luxury hotels.</p>

# %% [markdown]
# # Average Number of Rooms by Location

# %%
# Grouped location and calculated the average number of rooms
avg_rooms_location = df.groupby('Location')['Total Rooms'].mean().sort_values()

plt.figure(figsize=(12, 6))
sns.barplot(x=avg_rooms_location.index, y=avg_rooms_location.values, palette='coolwarm')

plt.title('Average Number of Rooms by Location', fontsize=16)
plt.xlabel('Location', fontsize=12)
plt.ylabel('Average Number of Rooms', fontsize=12)

plt.xticks(rotation=90, ha='right')
plt.tight_layout()
plt.show()

# %% [markdown]
# <h2 style="color:#4CAF50;">Code Explanation</h2>
#
# <pre style="background-color:#f9f9f9; padding:10px; border:1px solid #ddd;">
# # Grouped location and calculated the average number of rooms
# avg_rooms_location = df.groupby('Location')['Total Rooms'].mean().sort_values()
#
# plt.figure(figsize=(12, 6))
# sns.barplot(x=avg_rooms_location.index, y=avg_rooms_location.values, palette='coolwarm')
#
# plt.title('Average Number of Rooms by Location', fontsize=16)
# plt.xlabel('Location', fontsize=12)
# plt.ylabel('Average Number of Rooms', fontsize=12)
#
# plt.xticks(rotation=90, ha='right')
# plt.tight_layout()
# plt.show()
# </pre>
#
# <h3 style="color:#4CAF50;">1. Grouping Data:</h3>
# <p style="color:#555;">The first line groups the DataFrame <code>df</code> by <code>Location</code> and calculates the average number of rooms for each location:</p>
# <ul style="color:#555;">
#     <li><strong><code>df.groupby('Location')</code></strong>: Groups the data based on unique locations.</li>
#     <li><strong><code>['Total Rooms'].mean()</code></strong>: Calculates the mean of the <code>Total Rooms</code> column for each location.</li>
#     <li><strong><code>.sort_values()</code></strong>: Sorts the average number of rooms in ascending order.</li>
# </ul>
#
# <h3 style="color:#4CAF50;">2. Creating a Figure:</h3>
# <p style="color:#555;">This line initializes a new figure for the plot with specified dimensions:</p>
# <ul style="color:#555;">
#     <li><strong><code>plt.figure(figsize=(12, 6))</code></strong>: Creates a figure that is 12 inches wide and 6 inches tall.</li>
# </ul>
#
# <h3 style="color:#4CAF50;">3. Creating a Bar Plot:</h3>
# <p style="color:#555;">The <code>barplot()</code> function from Seaborn is used to create a bar plot:</p>
# <ul style="color:#555;">
#     <li><strong><code>sns.barplot(x=avg_rooms_location.index, y=avg_rooms_location.values, palette='coolwarm')</code></strong>:
#         <ul>
#             <li><code>x=avg_rooms_location.index</code>: Sets the x-axis to represent the different locations.</li>
#             <li><code>y=avg_rooms_location.values</code>: Sets the y-axis to represent the average number of rooms for each location.</li>
#             <li><code>palette='coolwarm'</code>: Specifies a color palette that transitions from cool to warm colors.</li>
#         </ul>
#     </li>
# </ul>
#
# <h3 style="color:#4CAF50;">4. Adding Title and Labels:</h3>
# <p style="color:#555;">The following lines add a title and axis labels to the plot:</p>
# <ul style="color:#555;">
#     <li><strong><code>plt.title('Average Number of Rooms by Location', fontsize=16)</code></strong>: Sets the title of the plot with a font size of 16.</li>
#     <li><strong><code>plt.xlabel('Location', fontsize=12)</code></strong>: Labels the x-axis with the specified text and font size.</li>
#     <li><strong><code>plt.ylabel('Average Number of Rooms', fontsize=12)</code></strong>: Labels the y-axis similarly.</li>
# </ul>
#
#
# <h3 style="color:#4CAF50;">5. Purpose:</h3>
# <p style="color:#555;">This code visualizes the average number of hotel rooms by location, providing insights into how room availability varies across different areas.</p>

# %% [markdown]
# # Lets check starting rates based on whether a hotel has a specific amenity?

# %%
# Created a new column for whether each amenity is available or not?
df['Has Swimming Pool'] = df['Hotel Ammenties'].str.contains('Swimming pool', case=False, na=False)
df['Has Spa'] = df['Hotel Ammenties'].str.contains('spa/wellness centre', case=False, na=False)

# Using melting for easier plotting
amenity_melted = df.melt(id_vars=['Starting Rate in ($)'], value_vars=['Has Swimming Pool', 'Has Spa'],
                          var_name='Amenity', value_name='Available')

plt.figure(figsize=(12, 6))
sns.boxplot(x='Amenity', y='Starting Rate in ($)', hue='Available', data=amenity_melted, palette='Set2')

plt.title('Starting Rates by Amenities (Swimming Pool and Spa)', fontsize=16)
plt.xlabel('Amenity', fontsize=12)
plt.ylabel('Starting Rate in ($)', fontsize=12)

plt.legend(title='Availability')
plt.tight_layout()
plt.show()

# %% [markdown]
# > Swimming Pool: Hotels with a swimming pool generally have higher starting rates than those without. The median starting rate for hotels with a swimming pool is around 2000 dollars, while for those without it's around 1000 dollars.
#
# > Spa: Hotels with a spa also tend to have higher starting rates, but the difference is less pronounced compared to the swimming pool. The median starting rate for hotels with a spa is around 1750 dollars.
#
# **Overall, the box plot suggests that having a swimming pool and/or a spa is associated with higher starting rates for luxury hotels. However, the impact of these amenities on the starting rate varies, with swimming pools having a more significant effect than spas.**

# %%
amenity_distribution = df['Hotel Ammenties'].str.split(',').explode().str.strip().value_counts()
top_amenities = amenity_distribution.head(5)

plt.figure(figsize=(8, 8))
plt.pie(top_amenities, labels=top_amenities.index, autopct='%1.1f%%', startangle=140, colors=sns.color_palette('pastel'))
plt.title('Top 5 Hotel Amenities Distribution', fontsize=16)
plt.axis('equal')  # Equal aspect ratio ensures that pie is drawn as a circle.
plt.show()

# %%
# Selecting only numeric columns for correlation
numeric_df = df.select_dtypes(include=['int64', 'float64'])

# Calculating the correlation matrix
correlation_matrix = numeric_df.corr()

# Plotting the heatmap
plt.figure(figsize=(10, 8))
sns.heatmap(correlation_matrix, annot=True, cmap='coolwarm', fmt=".2f", linewidths=.5)
plt.title('Correlation Heatmap of Hotel Data', fontsize=16)
plt.tight_layout()
plt.show()

# %% [markdown]
# <h2 style="color:#4CAF50;">Correlation Heatmap Analysis</h2>
#
# <p style="color:#555;">This image represents a correlation heatmap of hotel data, showing the relationship between three variables: <strong>Rank</strong>, <strong>Total Rooms</strong>, and <strong>Starting Rate (in $)</strong>. The values inside the squares represent the Pearson correlation coefficients between the variables, which can range from -1 to 1.</p>
#
# <h3 style="color:#4CAF50;">Interpretation:</h3>
#
# <ul style="color:#555;">
#     <li><strong>Rank vs. Rank (1.00)</strong>: This is the correlation of the same variable with itself, so it always equals 1.</li>
#     <li><strong>Total Rooms vs. Total Rooms (1.00)</strong>: Similarly, the correlation between Total Rooms and itself is also 1.</li>
#     <li><strong>Starting Rate vs. Starting Rate (1.00)</strong>: The same applies for Starting Rate.</li>
# </ul>
#
# <h3 style="color:#4CAF50;">Off-Diagonal Relationships:</h3>
# <ul style="color:#555;">
#     <li><strong>Rank vs. Total Rooms (-0.30)</strong>: This negative correlation means that as the number of rooms increases, the rank tends to decrease, indicating a moderately weak relationship.</li>
#     <li><strong>Rank vs. Starting Rate (0.01)</strong>: The correlation is very close to 0, meaning there is no meaningful relationship between rank and starting rate.</li>
#     <li><strong>Total Rooms vs. Starting Rate (-0.37)</strong>: This indicates a weak to moderate negative correlation, suggesting that hotels with more rooms tend to have lower starting rates.</li>
# </ul>
#
# <h3 style="color:#4CAF50;">Color Interpretation:</h3>
# <p style="color:#555;">The heatmap uses colors to visualize the strength and direction of the correlations:</p>
# <ul style="color:#555;">
#     <li><strong>Red</strong> represents positive correlations, with darker red indicating stronger correlations.</li>
#     <li><strong>Blue</strong> represents negative correlations, with darker blue indicating stronger negative correlations.</li>
# </ul>
#
# <h3 style="color:#4CAF50;">Summary:</h3>
# <p style="color:#555;">In summary, the heatmap indicates that:</p>
# <ul style="color:#555;">
#     <li>Rank and Total Rooms have a slight negative correlation.</li>
#     <li>Rank and Starting Rate have almost no correlation.</li>
#     <li>Total Rooms and Starting Rate have a weak negative correlation.</li>
# </ul>

# %%
sns.pairplot(numeric_df, diag_kind='kde', palette='coolwarm')
plt.suptitle('Pair Plot of Numeric Features', y=1.02)
plt.show()

# %% [markdown]
# <h2 style="color:#4CAF50;">Pair Plot Analysis</h2>
#
# <p style="color:#555;">This image displays a pair plot of numeric features from hotel data, focusing on the relationships between three variables: <strong>Rank</strong>, <strong>Total Rooms</strong>, and <strong>Starting Rate (in $)</strong>. The scatter plots and kernel density estimation (KDE) plots allow for visual assessment of the distributions and correlations among these variables.</p>
#
# <h3 style="color:#4CAF50;">Interpretation of Diagonal Plots:</h3>
# <ul style="color:#555;">
#     <li><strong>Rank Distribution:</strong> The KDE plot indicates a peak around lower ranks, suggesting that most hotels are ranked lower (higher rank numbers) within the dataset.</li>
#     <li><strong>Total Rooms Distribution:</strong> The plot is left-skewed, indicating that most hotels have a smaller number of total rooms, with a few outliers having a significantly larger number of rooms.</li>
#     <li><strong>Starting Rate Distribution:</strong> This plot shows a concentration of hotels at lower starting rates, with a few hotels having much higher rates.</li>
# </ul>
#
# <h3 style="color:#4CAF50;">Off-Diagonal Relationships:</h3>
# <ul style="color:#555;">
#     <li><strong>Rank vs. Total Rooms:</strong> The scatter plot shows a slight downward trend, indicating a weak negative correlation. As the number of rooms increases, the rank tends to decrease, suggesting that larger hotels might be ranked lower.</li>
#     <li><strong>Rank vs. Starting Rate:</strong> The plot does not show a clear trend, indicating that there is virtually no correlation between rank and starting rate, as the data points are widely dispersed.</li>
#     <li><strong>Total Rooms vs. Starting Rate:</strong> This relationship also displays a loose negative correlation, with some indication that hotels with more rooms may tend to have lower starting rates, although this is not strongly pronounced.</li>
# </ul>
#
# <h3 style="color:#4CAF50;">Color Interpretation:</h3>
# <p style="color:#555;">The pair plot uses scatter plots to visualize the relationships between pairs of variables:</p>
# <ul style="color:#555;">
#     <li><strong>Density of Points:</strong> Areas with a higher density of points indicate a stronger relationship, while scattered points suggest weak or no correlation.</li>
#     <li><strong>Trends:</strong> The general direction of the point distribution indicates the nature of the correlation (positive, negative, or none).</li>
# </ul>
#
# <h3 style="color:#4CAF50;">Summary:</h3>
# <p style="color:#555;">In summary, the pair plot indicates that:</p>
# <ul style="color:#555;">
#     <li>Rank and Total Rooms exhibit a slight negative correlation.</li>
#     <li>Rank and Starting Rate show almost no correlation.</li>
#     <li>Total Rooms and Starting Rate have a weak negative correlation.</li>
# </ul>
